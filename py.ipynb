# %%
import matplotlib.pyplot as plt
import json
import numpy as np

# %%
alts = json.load(open("geodata/terr.json", "r"))
plt.plot(alts[1])
# for alts_ in alts:
#   plt.plot(alts_)

# %%
alts = json.load(open("terr.json", "r"))
plt.plot(alts[0]) # MARGIN 5

# %%
alts = json.load(open("terr.json", "r"))
plt.plot(alts[0]) # MARGIN 5
